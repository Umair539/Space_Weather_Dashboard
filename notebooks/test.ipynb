# %%
import pandas as pd
from sqlalchemy import create_engine

# 1. Point to your database file
engine = create_engine("sqlite:///../data/transformed/noaa_data.db")

# 2. Define your query
query = (
    f"SELECT "
    f"strftime('%Y-%m-%d %H:00:00', time) AS hourly_bucket, "
    f"avg(speed) AS avg_speed "
    f"FROM solar "
    f"GROUP BY hourly_bucket "
    f"ORDER BY hourly_bucket ASC;"
)

# 3. Run and print
df = pd.read_sql(query, engine)
print(df)
# Out:
#            hourly_bucket   avg_speed
# 0    2026-03-06 14:00:00  340.963636
# 1    2026-03-06 15:00:00  343.909167
# 2    2026-03-06 16:00:00  342.343333
# 3    2026-03-06 17:00:00  340.666667
# 4    2026-03-06 18:00:00  336.836667
# ..                   ...         ...
# 164  2026-03-13 10:00:00  453.220333
# 165  2026-03-13 11:00:00  468.140000
# 166  2026-03-13 12:00:00  496.700000
# 167  2026-03-13 13:00:00  541.391667
# 168  2026-03-13 14:00:00  563.805319
#
# [169 rows x 2 columns]

# %%
# 2. Define your query
query = (
    f"SELECT * from solar_agg"
)

# 3. Run and print
df = pd.read_sql(query, engine)
print(df)
# Out:
#                            time  density_mean  density_std  density_iqr  \
# 0    2026-03-06 14:00:00.000000          3.91         0.19         0.22
# 1    2026-03-06 15:00:00.000000          4.80         1.02         1.20
# 2    2026-03-06 16:00:00.000000          5.09         0.79         0.87
# 3    2026-03-06 17:00:00.000000          5.07         0.65         0.94
# 4    2026-03-06 18:00:00.000000          5.14         0.89         0.82
# ..                          ...           ...          ...          ...
# 164  2026-03-13 10:00:00.000000          2.64         1.09         1.40
# 165  2026-03-13 11:00:00.000000          1.98         0.85         1.62
# 166  2026-03-13 12:00:00.000000          0.79         1.03         0.79
# 167  2026-03-13 13:00:00.000000          0.34         0.14         0.21
# 168  2026-03-13 14:00:00.000000          0.31         0.09         0.10
#
#      speed_mean  speed_std  speed_iqr  temperature_mean  temperature_std  \
# 0        340.96       2.04       0.75          78055.18         17382.01
# 1        343.91       4.77       4.12          64298.72         31108.76
# 2        342.34       4.07       5.05          68632.52         21585.56
# 3        340.67       3.65       4.50          58732.07         15231.11
# 4        336.84       3.85       5.95          49531.77          9490.20
# ..          ...        ...        ...               ...              ...
# 164      453.22      17.40      17.28         155151.56         49965.61
# 165      468.14      14.13      18.95         175933.80         48660.69
# 166      496.70      24.60      36.15         184336.45         47328.29
# 167      541.39      13.77      22.15         219665.33         41325.65
# 168      563.81       9.91      14.25         266042.89         64200.91
#
#      temperature_iqr  bz_mean  bz_std  bz_iqr  bt_mean  bt_std  bt_iqr  \
# 0           13352.00    -2.72    0.40    0.68     5.94    0.09    0.13
# 1           46647.50    -1.81    0.66    1.22     6.30    0.29    0.46
# 2           27020.75    -1.30    0.44    0.76     6.76    0.18    0.19
# 3           10634.50    -2.31    0.34    0.62     7.16    0.15    0.30
# 4           10017.75    -0.58    2.21    3.60     6.81    0.35    0.47
# ..               ...      ...     ...     ...      ...     ...     ...
# 164         73763.75     3.20    5.41    9.96     9.90    0.70    0.87
# 165         68596.25     3.99    4.01    7.97     9.39    1.60    1.85
# 166         69964.25     5.74    2.21    3.81    12.15    0.97    1.57
# 167         42648.25     2.93    1.34    2.19    12.73    0.40    0.80
# 168         96172.00     1.72    1.84    2.13    11.74    0.74    1.33
#
#      pressure_mean  pressure_std  pressure_iqr
# 0             0.76          0.04          0.03
# 1             0.95          0.22          0.26
# 2             1.00          0.18          0.20
# 3             0.98          0.14          0.21
# 4             0.97          0.17          0.19
# ..             ...           ...           ...
# 164           0.91          0.38          0.55
# 165           0.73          0.32          0.62
# 166           0.30          0.35          0.29
# 167           0.17          0.08          0.12
# 168           0.17          0.05          0.05
#
# [169 rows x 19 columns]

# %%
# 2. Define your query
query = f"SELECT COUNT(DISTINCT strftime('%Y-%m-%d %H', time)) AS unique_hour_count FROM solar;"

# 3. Run and print
df = pd.read_sql(query, engine)
print(df)
# Out:
#    unique_hour_count
# 0                169
