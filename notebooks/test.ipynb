# %%
import pandas as pd
from sqlalchemy import create_engine

# 1. Point to your database file
engine = create_engine("sqlite:///../data/transformed/noaa_data.db")

# 2. Define your query
query = (
    f"SELECT "
    f"strftime('%Y-%m-%d %H:00:00', time) AS hourly_bucket, "
    f"avg(speed) AS avg_speed "
    f"FROM solar "
    f"GROUP BY hourly_bucket "
    f"ORDER BY hourly_bucket ASC;"
)

# 3. Run and print
df = pd.read_sql(query, engine)
print(df)
# Out:
#            hourly_bucket   avg_speed
# 0    2026-03-06 14:00:00  340.963636
# 1    2026-03-06 15:00:00  343.909167
# 2    2026-03-06 16:00:00  342.343333
# 3    2026-03-06 17:00:00  340.666667
# 4    2026-03-06 18:00:00  336.836667
# ..                   ...         ...
# 164  2026-03-13 10:00:00  453.220333
# 165  2026-03-13 11:00:00  468.140000
# 166  2026-03-13 12:00:00  496.700000
# 167  2026-03-13 13:00:00  541.391667
# 168  2026-03-13 14:00:00  563.805319
#
# [169 rows x 2 columns]

# %%
# 2. Define your query
query = (
    f"SELECT * from solar"
)

# 3. Run and print
df = pd.read_sql(query, engine)
print(df)
# Out:
#                              time  density   speed  temperature    bz     bt  \
# 0      2026-03-06 14:49:00.000000     3.78  341.00      68245.0 -2.96   6.00
# 1      2026-03-06 14:50:00.000000     3.78  341.00      68245.0 -3.14   6.01
# 2      2026-03-06 14:51:00.000000     3.98  340.40      74367.0 -3.07   6.01
# 3      2026-03-06 14:52:00.000000     4.01  338.50      50967.0 -3.21   6.11
# 4      2026-03-06 14:53:00.000000     3.94  338.70      63757.0 -2.99   5.98
# ...                           ...      ...     ...          ...   ...    ...
# 10073  2026-03-13 14:42:00.000000     0.34  577.75     368541.5  0.91  10.74
# 10074  2026-03-13 14:43:00.000000     0.29  575.40     359178.0  0.91  10.88
# 10075  2026-03-13 14:44:00.000000     0.34  575.80     363466.0  1.57  10.62
# 10076  2026-03-13 14:45:00.000000     0.50  578.90     379097.0  2.20  10.17
# 10077  2026-03-13 14:46:00.000000     0.51  587.80     365195.0  4.64  10.33
#
#        pressure
# 0          0.74
# 1          0.74
# 2          0.77
# 3          0.77
# 4          0.76
# ...         ...
# 10073      0.19
# 10074      0.16
# 10075      0.19
# 10076      0.28
# 10077      0.29
#
# [10078 rows x 7 columns]

# %%
# 2. Define your query
query = f"SELECT COUNT(DISTINCT strftime('%Y-%m-%d %H', time)) AS unique_hour_count FROM solar;"

# 3. Run and print
df = pd.read_sql(query, engine)
print(df)
# Out:
#    unique_hour_count
# 0                169
