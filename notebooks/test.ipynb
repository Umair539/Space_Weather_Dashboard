# %%
import pandas as pd

# %%
solar = pd.read_csv('../data/transformed/solar.csv')
solar.loc[:, 'time'] = pd.to_datetime(solar['time']) 
solar.set_index('time', inplace=True)
solar[['speed']]
# Out:
# c:\Users\Umair\Documents\Digital_Futures\Capstone\.venv\Lib\site-packages\pandas\core\indexes\base.py:7654: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)
#                      speed
# time
# 2025-11-26 13:28:00  718.2
# 2025-11-26 13:29:00  707.7
# 2025-11-26 13:30:00  693.4
# 2025-11-26 13:31:00  694.6
# 2025-11-26 13:32:00  697.7
# ...                    ...
# 2025-12-03 13:21:00  395.6
# 2025-12-03 13:22:00  397.2
# 2025-12-03 13:23:00  403.4
# 2025-12-03 13:24:00  394.2
# 2025-12-03 13:25:00  395.1
#
# [10078 rows x 1 columns]

# %%
solar.index.name
# Out:
# 'time'

# %%
def interpolate_missing_data(df):
    df = df.interpolate(method="linear", axis=0).ffill().bfill()
    return df

# %%
df = pd.DataFrame(
    {
        "speed": [1, 2, 3, 4, None, None, 7, 8, 9, 10],
    }
)
r = interpolate_missing_data(df)

# %%
r.isnull().sum().sum()
# Out:
# np.int64(0)
