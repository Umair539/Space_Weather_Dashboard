# %%
import pandas as pd
from sqlalchemy import create_engine

# 1. Point to your database file
engine = create_engine("sqlite:///../data/transformed/noaa_data.db")

# 2. Define your query
query = "SELECT * FROM solar LIMIT 10"

# 3. Run and print
df = pd.read_sql(query, engine)
print(df)
# Out:
#                          time  density  speed  temperature    bz    bt  \
# 0  2026-03-06 14:49:00.000000     3.78  341.0      68245.0 -2.96  6.00
# 1  2026-03-06 14:50:00.000000     3.78  341.0      68245.0 -3.14  6.01
# 2  2026-03-06 14:51:00.000000     3.98  340.4      74367.0 -3.07  6.01
# 3  2026-03-06 14:52:00.000000     4.01  338.5      50967.0 -3.21  6.11
# 4  2026-03-06 14:53:00.000000     3.94  338.7      63757.0 -2.99  5.98
# 5  2026-03-06 14:54:00.000000     4.27  345.3     114184.0 -2.80  5.91
# 6  2026-03-06 14:55:00.000000     4.19  344.1     101031.0 -2.74  5.83
# 7  2026-03-06 14:56:00.000000     3.87  340.2      74342.0 -2.42  5.85
# 8  2026-03-06 14:57:00.000000     3.73  340.4      81410.0 -2.10  5.81
# 9  2026-03-06 14:58:00.000000     3.65  340.3      80275.0 -2.29  5.92
#
#    pressure
# 0      0.74
# 1      0.74
# 2      0.77
# 3      0.77
# 4      0.76
# 5      0.85
# 6      0.83
# 7      0.75
# 8      0.72
# 9      0.71
